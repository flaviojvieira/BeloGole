# %% [markdown]
# # Notebook para processar tabela_preços.ods
# Este notebook lê a planilha ODS, limpa os dados de produtos e gera uma saída pronta para o cardápio do site.

# %%
import os
import re
import pandas as pd
import numpy as np
from pathlib import Path

print('Pandas version:', pd.__version__)

# %%
planilha = Path(r'c:/Users/jsfla/OneDrive/Documentos/Flávio/Trabalhos/Belo Gole - Joao Paulo/tabela_preços.ods')
print('Arquivo existe:', planilha.exists())
print('Caminho:', planilha)

try:
    df = pd.read_excel(planilha, engine='odf')
    print(df.head())
    print('\nColunas:', list(df.columns))
except Exception as e:
    print('Erro ao ler a planilha:', e)
